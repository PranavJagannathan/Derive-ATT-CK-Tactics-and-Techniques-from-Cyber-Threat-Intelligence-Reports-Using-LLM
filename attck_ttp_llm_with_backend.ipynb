# %%
# Install necessary dependencies
# !pip install transformers pandas google-colab reportlab

# %%
import pandas as pd
import re
from google.colab import files
from transformers import pipeline
import google.generativeai as genai

# %%
# Initialize Gemini API key (make sure you have your Gemini API key from Google Cloud)
genai.configure(api_key="AIzaSyDGRQjmyxAEhLFmU7_c4DSf4W0JbwQtg44")  # Replace with your actual Gemini API key

# %%
# Upload CSV file
uploaded = files.upload()

# Read the uploaded CSV file
file_name = list(uploaded.keys())[0]  # Get the uploaded file name
df = pd.read_csv(file_name)  # Read CSV

# Extract text (assuming the first column contains the unstructured CTI report)
raw_cti_report = " ".join(df.iloc[:, 0].astype(str).tolist())  # Convert to string
# Out:
#      <input type="file" id="files-721479ab-f1a8-4ee6-a78b-fcd8c987ecdf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-721479ab-f1a8-4ee6-a78b-fcd8c987ecdf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Preprocess the extracted text
import re
import re

# Function to preprocess text
def preprocess_text(text):
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    text = re.sub(r'[^\w\s.,]', '', text)  # Remove special characters except punctuation
    return text.strip()
cleaned_text = preprocess_text(raw_cti_report)
print("Cleaned Text:\n", cleaned_text)
# Out:
# Cleaned Text:
# ...

# %%
# Define a fully autonomous prompt to Gemini model to extract relevant details
prompt = f"""
You are a Cybersecurity Threat Intelligence Analyst. Analyze the following Cyber Threat Intelligence (CTI) report and extract the following:

- ATT&CK Tactics
- ATT&CK Techniques (TXXXX format)
- Indicators of Compromise (IOCs)
- Any other relevant details that can help in understanding the attack
- Severity score (Low, Medium, High, Critical)
-Last give a small summary on how the attack has been taken by making it as a description

Text: {cleaned_text}
"""

# Use Gemini API to generate structured intelligence
model = genai.GenerativeModel("gemini-1.5-pro")
response = model.generate_content(prompt)  # No need for text=

# Extract structured output from Gemini response
structured_output = response.text  # Correct way to extract text

# Postprocess the model output to format the information into a report
def postprocess_output(output):
    """
    Formats and returns the extracted details from the AI-generated text.
    """
    return output.strip()

# Process the output from Gemini model
structured_text = postprocess_output(structured_output)

# Print structured text (No predefined IOCs or tactics, model handles it)
print("\nFormatted Structured Report:\n", structured_text)
# Out:
# Formatted Structured Report:
#  ## CTI Report Analysis
#
# **ATT&CK Tactics:**
#
# * Initial Access: Phishing
# * Execution: Command and Scripting Interpreter (PowerShell)
# * Persistence: Scheduled Task/Job, Registry Run Keys / Startup Folder
# * Command and Control:  Application Layer Protocol (HTTPS),  DNS
# * Exfiltration: DNS
#
# **ATT&CK Techniques:**
#
# * T1566: Phishing
# * T1059: Command and Scripting Interpreter (PowerShell)
# * T1053: Scheduled Task/Job
# * T1547: Boot or Logon Autostart Execution (Implied - registry keys)
# * T1071: Application Layer Protocol (HTTPS)
# * T1568: Dynamic Resolution
# * T1027: Obfuscated Files or Information (Implied - DNS Tunneling as a means of hiding data exfiltration)
#
#
# **Indicators of Compromise (IOCs):**
#
# * **Email Subjects:** "Urgent Account Verification Required", "Payroll Update March 2025"
# * **Attachments:** Invoice_March2025.pdf.exe, payment_receipt_2025.docm
# * **Script:** update.ps1
# ...

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

def generate_pdf_report(structured_text, filename="CTI_Structured_Report.pdf"):
    """
    Converts structured threat intelligence text into a PDF report.
    """
    c = canvas.Canvas(filename, pagesize=letter)
    width, height = letter
    c.setFont("Helvetica-Bold", 16)

    # Title
    c.drawString(100, height - 50, "Cyber Threat Intelligence Report")
    c.setFont("Helvetica", 12)
    y_position = height - 80  # Adjust starting height for content
    line_height = 14  # Line spacing

    # Function to write text while handling page overflow
    def write_text(text, font="Helvetica", size=12):
        nonlocal y_position
        c.setFont(font, size)
        lines = text.split("\n")

        for line in lines:
            if y_position - line_height < 40:  # Avoid cutting off text at bottom
                c.showPage()  # New page
                c.setFont(font, size)
                y_position = height - 50  # Reset position at the top

            c.drawString(100, y_position, line)
            y_position -= line_height  # Move cursor down

    # Write the structured report into the PDF
    write_text(structured_text)

    # Save PDF
    c.save()
    print(f"✅ Report saved as '{filename}'")

    # Download PDF (Colab only)
    from google.colab import files
    files.download(filename)

# ✅ Generate PDF from structured text
generate_pdf_report(structured_text)
# Out:
# ✅ Report saved as 'CTI_Structured_Report.pdf'

# %%
# !ngrok authtoken 2v8BDIiYTwggtfeR0BUS1og7K00_6hNa6MJYmnXrbDe7ryxV9
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# Install necessary packages (Run this once in Colab)
# !pip install flask pyngrok streamlit google-generativeai

import google.generativeai as genai
from flask import Flask, request, jsonify
from threading import Thread
import random
from pyngrok import ngrok

# 🌟 Replace with your actual API Key
GEMINI_API_KEY = "AIzaSyDGRQjmyxAEhLFmU7_c4DSf4W0JbwQtg44"

# ✅ Authenticate Gemini API
genai.configure(api_key=GEMINI_API_KEY)

# ✅ Initialize Flask app
app = Flask(__name__)

# ✅ Ngrok Authentication Token (Replace with your actual Ngrok token)
ngrok.set_auth_token("2v8BDIiYTwggtfeR0BUS1og7K00_6hNa6MJYmnXrbDe7ryxV9")

# ✅ Generate a random port number (between 4000-6000)
PORT = random.randint(4000, 6000)

@app.route('/')
def home():
    return "🚀 Flask API for Cyber Threat Intelligence Processing is Running!"

@app.route('/analyze', methods=['POST'])
def analyze():
    # ✅ Check if JSON input exists
    req_data = request.get_json()
    if not req_data or "text" not in req_data:
        return jsonify({"error": "No text provided"}), 400

    text = req_data["text"]

    # ✅ Define a powerful prompt for Gemini
    prompt = f"""
    You are a Cybersecurity Threat Intelligence Analyst. Analyze the following Cyber Threat Intelligence (CTI) report and extract:

    - ATT&CK Tactics
    - ATT&CK Techniques (TXXXX format)
    - Indicators of Compromise (IOCs)
    - Relevant details to understand the attack
    - Severity score (Low, Medium, High, Critical)
    - Summary of how the attack was executed

    Text: {text}
    """

    try:
        # ✅ Use Gemini API to process the text
        model = genai.GenerativeModel("gemini-1.5-pro")
        response = model.generate_content(prompt)

        # ✅ Extract and clean the response text
        structured_output = response.text.strip() if response.text else "No response from Gemini."

    except Exception as e:
        return jsonify({"error": f"Gemini API error: {str(e)}"}), 500

    return jsonify({"structured_output": structured_output})

# ✅ Start Flask server in a separate thread
def run_flask():
    app.run(port=PORT, debug=True, use_reloader=False)

flask_thread = Thread(target=run_flask)
flask_thread.start()

# ✅ Expose Flask server using Ngrok
public_url = ngrok.connect(PORT).public_url
print(f"Public URL: {public_url}")
# Out:
# ...
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:4597
# INFO:werkzeug:Press CTRL+C to quit
# Public URL: https://4641-35-240-206-219.ngrok-free.app

# %%
from pyngrok import ngrok
ngrok.kill()  # Kill all active tunnels
public_url = ngrok.connect(5000)  # Start a new tunnel on port 5000
print(f"New Public URL: {public_url}")
# Out:
# WARNING:pyngrok.process.ngrok:t=2025-04-01T14:21:14+0000 lvl=warn msg="ngrok config file found at both XDG and legacy locations, using XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# New Public URL: NgrokTunnel: "https://cbd6-35-240-206-219.ngrok-free.app" -> "http://localhost:5000"
